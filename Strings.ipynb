# %% [markdown]
# # String Manipulation

# %% [markdown]
# ## Conctenating

# %%
S = "Hi"
Y = "Sunshine"
S+Y
# Out:
# 'HiSunshine'

# %%
S+" "+Y+" smile"
# Out:
# 'Hi Sunshine smile'

# %% [markdown]
# ### String conversion

# %%
101 + "dalmations"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-f5fff42749a6> in <cell line: 1>()
# ----> 1 101 + "dalmations"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
"101" + dalmations
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b84b1264b1dc> in <cell line: 1>()
# ----> 1 "101" + dalmations
#
# NameError: name 'dalmations' is not defined

# %%
"101" + " "+"dalmations"
# Out:
# '101 dalmations'

# %%
name ="rainbow" #"salt and pepper"
num = 7 #2
# f"Name is {name} and has {num} colors"
"Name is " + name +" and has " + str(num) +" colors"
# Out:
# 'Name is rainbow and has 7 colors'

# %%
#get the ascii value
ord("a"), ord("z"), ord("A"), ord("Z"), ord(" "), ord("!")
# Out:
# (97, 122, 65, 90, 32, 33)

# %%
al= "u"
chr(ord(al)+1)
# Out:
# 'v'

# %% [markdown]
# ### Indexing

# %%
S1 = "It is a lovely day"

# %%
S1[0] #first element
# Out:
# 'I'

# %%
S1[-1] #last element
# Out:
# 'y'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Splicing
#
# [from : to: step]
#
# *to index is omitted*

# %%
S1[0:5]
# Out:
# 'It is'

# %%
S1[3:]
# Out:
# 'is a lovely day'

# %%
S1[:5]
# Out:
# 'It is'

# %%
S1[8:18]
# Out:
# 'lovely day'

# %%
S1[-1]
# Out:
# 'y'

# %%
S1[:-1]
# Out:
# 'It is a lovely da'

# %%
S1[-3:]
# Out:
# 'day'

# %%
S1[0:12:3] #indexes 0,3,6,9
# Out:
# 'Iiao'

# %%
S1[::-1] #reverses the string it can be interpreted as S1[17::-1]
# Out:
# 'yad ylevol a si tI'

# %%
S1[17::-1]
# Out:
# 'yad ylevol a si tI'

# %% [markdown]
# ### Useful string functions

# %% [markdown]
# ##### replace

# %%
statement = "Every cloud has a silver lining"

statement.replace(" ","_")
# Out:
# 'Every_cloud_has_a_silver_lining'

# %% [markdown]
# ##### find

# %%
statement.find("silver"), statement.find("a"), statement.find("gold")
# Out:
# (18, 13, -1)

# %% [markdown]
# ##### count

# %%
statement.count("a"), statement.count("a",0,5 )
# Out:
# (2, 0)

# %% [markdown]
# ##### split

# %%
statement.split("a")
# Out:
# ['Every cloud h', 's ', ' silver lining']

# %%
spaces_stmt = "I have spaces   "
spaces_stmt.rstrip()
# Out:
# 'I have spaces'

# %%
spaces_stmt.lstrip()
# Out:
# 'I have spaces   '

# %%
spaces_stmt.strip()
# Out:
# 'I have spaces'

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...
